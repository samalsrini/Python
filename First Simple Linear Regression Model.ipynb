# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mat

# %%
ds = pd.read_csv('Desktop/Python Codes/Simple.csv')

# %%
ds
# Out:
#     AvgUnempRate  RGDPGrowth
# 0            8.7        -8.5
# 1           15.9        -6.4
# 2           23.6       -12.9
# 3           24.9        -1.2
# 4           21.7        10.8
# 5           20.1         8.9
# 6           16.9        12.9
# 7           14.3         5.1
# 8           19.0        -3.3
# 9           17.2         8.0
# 10          14.6         8.8
# 11           9.9        17.7
# 12           4.7        18.9
# 13           1.9        17.0
# 14           1.2         8.0
# 15           1.9        -1.0
# 16           3.9       -11.6
# 17           3.6        -1.1
# 18           4.0         4.1
# 19           6.6        -0.6
# 20           4.3         8.7
# 21           3.1         8.0
# 22           2.7         4.1
# 23           4.5         4.7
# 24           5.0        -0.6
# 25           4.2         7.1
# 26           4.2         2.1
# 27           5.2         2.1
# 28           6.2        -0.7
# 29           5.3         6.9
# ..           ...         ...
# ...

# %%
x= ds.drop(['AvgUnempRate'],axis=1) # or write this incase of one independent variable x = ds.RGDPGrowth
y = ds.AvgUnempRate
print(x.head(10))
print("\n")  # for a space in the output
print(y.head(10))
# Out:
#    RGDPGrowth
# 0        -8.5
# 1        -6.4
# 2       -12.9
# 3        -1.2
# 4        10.8
# 5         8.9
# 6        12.9
# 7         5.1
# 8        -3.3
# 9         8.0
#
#
# 0     8.7
# 1    15.9
# 2    23.6
# 3    24.9
# 4    21.7
# 5    20.1
# 6    16.9
# 7    14.3
# 8    19.0
# 9    17.2
# Name: AvgUnempRate, dtype: float64

# %%
# splitting the data into training and testing 
# sklearn is the package/library for ML functions

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split (x,y, test_size=0.3, random_state=6)

print(x_train)
print("\n")
print(y_train)
# Out:
#     RGDPGrowth
# 65         2.7
# 67         4.4
# 41         3.3
# 64         4.0
# 53         4.6
# 12        18.9
# 74         3.8
# 47         4.6
# 7          5.1
# 44        -0.5
# 24        -0.6
# 22         4.1
# 35         6.4
# 18         4.1
# 81         1.6
# 11        17.7
# 78        -0.1
# 3         -1.2
# 88         2.9
# 52        -1.8
# 42         5.3
# 6         12.9
# 54         7.2
# 40        -0.2
# 14         8.0
# 86         1.6
# 50        -0.3
# 69         4.8
# 70         4.1
# 28        -0.7
# ..         ...
# 60         1.9
# 72         1.7
# 16       -11.6
# 83         1.8
# 37         2.5
# 4         10.8
# 49         3.2
# 43         5.6
# 15        -1.0
# 85         2.9
# 5          8.9
# 66         3.8
# 31         2.3
# 2        -12.9
# 8         -3.3
# 76         2.9
# 68         4.5
# 33         4.4
# 26         2.1
# 57         3.5
# 77         1.9
# 75         3.5
# 1         -6.4
# 25         7.1
# 62         3.5
# 80         2.6
# ...

# %%
print(x_test)
print("\n")
print(y_test)
# Out:
#     RGDPGrowth
# 17        -1.1
# 34         5.8
# 32         6.1
# 0         -8.5
# 71         1.0
# 39         3.1
# 36         6.5
# 63         2.8
# 46         5.4
# 30         2.6
# 58         4.2
# 20         8.7
# 82         2.3
# 51         2.5
# 59         3.7
# 23         4.7
# 38         4.8
# 13        17.0
# 87         2.2
# 45        -0.2
# 27         2.1
# 61        -0.1
# 9          8.0
# 29         6.9
# 48         5.5
# 55         4.2
# 56         3.5
#
#
# 17     3.6
# 34     5.0
# 32     5.5
# 0      8.7
# 71     5.7
# 39     3.5
# 36     3.8
# 63     6.5
# 46     7.8
# 30     6.6
# 58     5.3
# 20     4.3
# 82     7.9
# 51     8.5
# 59     5.4
# 23     4.5
# 38     3.4
# 13     1.9
# 87     4.1
# 45     8.2
# 27     5.2
# 61     7.3
# 9     17.2
# 29     5.3
# 48     6.0
# 55     7.0
# 56     6.6
# Name: AvgUnempRate, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)   # fitting my training data to algo for understadning pattern
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
M=regressor.coef_                # slope
C=regressor.intercept_           # interecept

# %%
print("Coefficent(M)=", regressor.coef_)
print("Intercept (C)=", regressor.intercept_)
# Out:
# Coefficent(M)= [-0.12494627]
# Intercept (C)= 7.943381999634099

# %%
# predicting the test set results
y_predict = regressor.predict(x_test)
print(y_predict)
print("\n")
print(y_test)
# Out:
# [8.0808229  7.21869363 7.18120975 9.0054253  7.81843573 7.55604856
#  7.13123124 7.59353244 7.26867214 7.6185217  7.41860766 6.85634944
#  7.65600558 7.63101632 7.4810808  7.35613453 7.3436399  5.8192954
#  7.6685002  7.96837125 7.68099483 7.95587663 6.94381183 7.08125273
#  7.25617751 7.41860766 7.50607005]
#
#
# 17     3.6
# 34     5.0
# 32     5.5
# 0      8.7
# 71     5.7
# 39     3.5
# 36     3.8
# 63     6.5
# 46     7.8
# 30     6.6
# 58     5.3
# 20     4.3
# 82     7.9
# 51     8.5
# 59     5.4
# 23     4.5
# 38     3.4
# 13     1.9
# 87     4.1
# 45     8.2
# 27     5.2
# 61     7.3
# 9     17.2
# 29     5.3
# 48     6.0
# 55     7.0
# 56     6.6
# Name: AvgUnempRate, dtype: float64

# %%
# understanding error. Lower the error, that good is to predict

from sklearn import metrics
print ("MAE=", metrics.mean_absolute_error(y_test, y_predict))
print ("MSE=", metrics.mean_squared_error(y_test, y_predict))
print ("RMSE", np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# MAE= 2.258467832087487
# MSE= 9.185980978539014
# RMSE 3.0308383293305194

# %%
from sklearn.metrics import r2_score  # how good is the model based on R2--correltaion coefficient..R2 higher the better

print('R2:', r2_score(y_test, y_predict))
# Out:
# R2: -0.2009002624239986

# %%
# only around 20% of the model is accurate/20% of the variance explained/20% confident.R2 ranges from -1 to +1

# %%
y_predict = regressor.predict([[1]])
y_predict
# Out:
# array([7.81843573])

# %%
# Cross validation

from sklearn.model_selection import cross_val_score

regression_avg = cross_val_score(estimator = regressor, x = x_train, y = y_train, cv=5, scoring='neg_mean_absolute_error')
print("cross val mean absolute error", regression.avg.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-43fd5ce541be> in <module>
#       3 from sklearn.model_selection import cross_val_score
#       4
# ----> 5 regression_avg = cross_val_score(estimator = regressor, x = x_train, y = y_train, cv=5, scoring='neg_mean_absolute_error')
#       6 print("cross val mean absolute error", regression.avg.mean())
#
# TypeError: cross_val_score() got an unexpected keyword argument 'x'
